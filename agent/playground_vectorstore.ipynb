# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_community import BigQueryVectorStore
import os
from dotenv import load_dotenv
from langchain_chroma import Chroma
load_dotenv()
# Out:
# True

# %%
dataset: str = "vector_store"
REGION: str = "europe-north2"
model_name: str = "models/gemini-embedding-001"
PROJECT_ID = os.getenv("GOOGLE_CLOUD_PROJECT")
DATASET = "vector_store"
TABLE = "attachments"
embedding = GoogleGenerativeAIEmbeddings(model=model_name)
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap=200)

# %%
with open("/Users/sigvardbratlie/Documents/Projects/master-thesis/data/THRD-2021-163881/01_fabricated/2019-06-01_00_kjøpskontrakt_2019-06-01.txt", "r") as f:
    text = f.read()

# %%
docs = splitter.split_text(text)
len(docs)
# Out:
# 3

# %%
embedding.embed_documents(docs)
# Out:
# [[-0.0063713416,
#   0.01252973,
#   0.0086291935,
#   -0.06428751,
#   0.0019226271,
#   0.020271918,
#   0.031958368,
#   -0.015129369,
#   0.027749367,
#   0.0024882935,
#   -0.03640678,
#   -0.020843947,
#   0.014589249,
#   0.017083017,
#   0.11992766,
#   0.004700651,
#   -0.014109388,
#   0.004692435,
#   -0.014057488,
#   -0.03653831,
#   0.017528698,
#   -0.00030865514,
#   0.013600389,
#   0.005690178,
#   0.015121246,
#   -0.011589209,
#   0.0017273611,
#   0.014485175,
#   0.035676923,
#   -0.027274651,
#   0.010383023,
#   0.021811744,
#   -0.012239726,
#   0.011241055,
#   0.002497834,
#   0.02058509,
#   0.01637203,
#   -0.006094408,
#   -0.023334634,
#   0.011995638,
#   -0.020105306,
#   -0.016748384,
#   -0.015232712,
#   -0.011493344,
#   -0.006149867,
#   0.009341388,
#   0.026822753,
#   -0.014608963,
#   0.0047257915,
#   0.009579114,
#   -0.005020148,
#   -0.025761988,
#   -0.008690623,
#   -0.17725545,
#   0.011245772,
#   -0.027279224,
#   -0.004264535,
# ...

# %%
file = '/Users/sigvardbratlie/Documents/Projects/master-thesis/data/TOSL-2024-125319/02_org_pdf/2022-01-25_B18 Epikriser fra OUS Ullevål.pdf'
with open(file, "rb") as f:
    pdf_data = f.read()

# %%
from database.vectorstore_modules import DocumentProcessor
dp = DocumentProcessor()

# %%
docs
# Out:
# [Document(metadata={'source': 'Gen-F_infomøte_2025_2026.pdf', 'total_pages': 105, 'creator': 'Canon iPR C270  PDF', 'page': 1}, page_content='(Page 5  of  36)'),
#  Document(metadata={'source': 'Gen-F_infomøte_2025_2026.pdf', 'total_pages': 105, 'creator': 'Canon iPR C270  PDF', 'page': 2}, page_content='(Page 6  of  36)'),
#  Document(metadata={'source': 'Gen-F_infomøte_2025_2026.pdf', 'total_pages': 105, 'creator': 'Canon iPR C270  PDF', 'page': 3}, page_content='(Page 7  of  36)'),
#  Document(metadata={'source': 'Gen-F_infomøte_2025_2026.pdf', 'total_pages': 105, 'creator': 'Canon iPR C270  PDF', 'page': 4}, page_content='(Page 8  of  36)'),
#  Document(metadata={'source': 'Gen-F_infomøte_2025_2026.pdf', 'total_pages': 105, 'creator': 'Canon iPR C270  PDF', 'page': 5}, page_content='(Page 9  of  36)'),
#  Document(metadata={'source': 'Gen-F_infomøte_2025_2026.pdf', 'total_pages': 105, 'creator': 'Canon iPR C270  PDF', 'page': 6}, page_content='(Page 10  of  36)'),
# ...

# %%
import ocrmypdf
import tempfile

# %%
import ocrmypdf
import tempfile
from pathlib import Path

def ocr_bytes(pdf_data: bytes) -> bytes:
    with tempfile.NamedTemporaryFile(suffix=".pdf") as inp, \
         tempfile.NamedTemporaryFile(suffix=".pdf") as out:

        inp.write(pdf_data)
        inp.flush()

        ocrmypdf.ocr(
            inp.name,
            out.name,
            deskew=True,
            force_ocr=True
        )

        out.seek(0)
        return out.read()

# %%
res = ocr_bytes(pdf_data)
# Out:
# Ghostscript 10.6.x contains JPEG encoding errors that may corrupt images. OCRmyPDF will attempt to mitigate, but this version is strongly not recommended. Please upgrade to a newer version. As of 2025-12, 10.6.0 is the latest version of Ghostscript.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# [tesseract] lots of diacritics - possibly poor OCR
# ...

# %%
from PyPDF2 import PdfReader
from io import BytesIO
import logging
from langchain_core.documents import Document
logger = logging.getLogger(__name__)
content_bytes = res
metadata = {"source": "Gen-F_infomøte_2025_2026.pdf"}

count_without_text = 0
try:
    reader = PdfReader(BytesIO(content_bytes))
except Exception as e:
    logger.error(f"Error reading PDF: {e}")
docs = []
base_meta = metadata | {
    "total_pages": len(reader.pages),
    "creator": reader.metadata.get("/Creator") if reader.metadata else None
}

for i, page in enumerate(reader.pages):
    if not page.extract_text():
        count_without_text += 1
        logger.debug(f"Page {i + 1} has no extractable text.")
        continue
        # docs.append(Document(
        #     page_content="No text",
        #     metadata={**base_meta, "page": i + 1, "note": "No extractable text"}
        # ))
    else:
        docs.append(Document(
            page_content=page.extract_text(),
            metadata={**base_meta, "page": i + 1}
        ))
    
if not docs or count_without_text == len(reader.pages):
    logger.warning("No pages extracted from PDF.")

logger.debug(f"Extracted {len(docs)} pages with text out of {len(reader.pages)} total pages.")

# %%
docs[0].model_dump()
# Out:
# {'id': None,
#  'metadata': {'source': 'Gen-F_infomøte_2025_2026.pdf',
#   'total_pages': 105,
#   'creator': 'OCRmyPDF 16.13.0 / Tesseract OCR-hOCR 5.5.1',
#   'page': 1},
# ...

# %%
with open("/Users/sigvardbratlie/Downloads/testocr.pdf", "wb") as f:
    f.write(res)

# %%
import uuid

# %%
is_valid_uuid("hei")
# Out:
# False
