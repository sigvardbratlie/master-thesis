# %% [markdown]
# # LOVDATA DATA EMBEDDING
# ### Embedds data to Big Query Vectore Store

# %%
from data.utils import ExtractLovData
from pathlib import Path
from langchain_core.documents import Document
import logging
logger = logging.getLogger(__name__)

# %%
extractor = ExtractLovData()
docs = extractor.load_docs("./nl")
# Out:
# INFO:data.utils:Loading cached documents for nl-19870612-048.xml
# INFO:data.utils:Loading cached documents for nl-19330519-011.xml
# INFO:data.utils:Loading cached documents for nl-19320422-001.xml
# INFO:data.utils:Loading cached documents for nl-20080515-035.xml
# INFO:data.utils:Loading cached documents for nl-19980717-054.xml
# INFO:data.utils:Loading cached documents for nl-20240625-067.xml
# INFO:data.utils:Loading cached documents for nl-19650625-001.xml
# INFO:data.utils:Loading cached documents for nl-20160617-044.xml
# INFO:data.utils:Loading cached documents for nl-20171215-107.xml
# INFO:data.utils:Loading cached documents for nl-19840608-058.xml
# INFO:data.utils:Loading cached documents for nl-20090619-101.xml
# INFO:data.utils:Loading cached documents for nl-19940616-020.xml
# INFO:data.utils:Loading cached documents for nl-20030314-015.xml
# INFO:data.utils:Loading cached documents for nl-20031128-098.xml
# ...

# %%
import json

with open("cached_docs.json", "r") as f:
    contents = json.load(f)

for file, docs in contents.items():
    for doc in docs:
        doc.get("metadata").pop("embedding")

with open("cached_docs.json", "w") as f:
    json.dump(contents, f, indent=2)

# %% [markdown]
# ## Embedd to Vector Store

# %%
import os
os.chdir("../../agent")
os.getcwd()
from database import BQVectorStore
# Out:
# INFO:pikepdf._core:pikepdf C++ to Python logger bridge initialized

# %%
from dotenv import load_dotenv
load_dotenv()
len(docs), os.getenv("GOOGLE_API_KEY"), os.getenv("GEMINI_API_KEY"), os.getcwd()
# Out:
# (27454,
#  'AIzaSyA-JYmEWePwco2_KPAre8w9-E3kQ1YPihE',
#  None,
#  '/Users/sigvardbratlie/Documents/Projects/master-thesis/agent')

# %%
import json
print(docs[0].page_content)
print("\n\n")
print(json.dumps(docs[0].metadata, indent = 2))

if "embedding" in docs[0].metadata:
    raise ValueError("Documents should not have embeddings at this point. Please check the code.")
# Out:
# På begjæring kan maskindrevne passasjerskip, lasteskip og luftputefartøy samt boreplattformer og andre flyttbare innretninger, registreres i norsk internasjonalt skipsregister når de ikke er innført i et annet lands register, og: eieren tilfredsstiller nasjonalitetsvilkårene i sjøloven § 1 ; eller eieren, dersom denne ikke tilfredsstiller nasjonalitetsvilkårene i sjøloven § 1 , er aksjeselskap, allmennaksjeselskap eller kommandittselskap med hovedkontor i Norge; eller er partrederi, med bestyrende reder som tilfredsstiller bestemmelsene om bestyrende reder i sjøloven kapittel 5. Eieren, dersom denne ikke tilfredsstiller vilkårene i pkt 1 eller 2, har oppnevnt en representant som har fullmakt til å ta imot søksmål på vegne av eieren. Representanten må fylle de nasjonalitetskrav som stilles til bestyrende reder i sjøloven § 103 .
# eieren tilfredsstiller nasjonalitetsvilkårene i sjøloven § 1 ; eller
# ...

# %%
vs = BQVectorStore()
vs.add_documents(docs[10:], collection_id="laws")
# Out:
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
# INFO:langchain_google_community.bq_storage_vectorstores._base:BigQuery table master-thesis-26.vector_store.laws initialized/validated as persistent storage. Access via BigQuery console:
#  https://console.cloud.google.com/bigquery?project=master-thesis-26&ws=!1m5!1m4!4m3!1smaster-thesis-26!2svector_store!3slaws
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-embedding-001:batchEmbedContents "HTTP/1.1 200 OK"
