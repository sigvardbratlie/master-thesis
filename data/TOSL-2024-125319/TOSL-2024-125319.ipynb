# %%
from data.utils import *
from pathlib import Path
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from data.utils import *
#       2 from pathlib import Path
#       3 import logging
#
# File ~/Documents/Projects/master-thesis/data/src/data/utils.py:2
# ----> 2 import PyPDF2
#       3 from pathlib import Path
#       4 import re
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
for file in Path("./02_org_pdf/Bilag til stevning").glob("*"):
    rename_file_with_date(file, rename=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 for file in Path("./02_org_pdf/Bilag til stevning").glob("*"):
#       2     rename_file_with_date(file, rename=False)
#
# NameError: name 'Path' is not defined

# %%
for file in Path("./02_org_pdf/Bilag til stevning").glob("*.pdf"):
    rename_pdf_with_date(file, rename=False)
# Out:
# INFO:data.utils:----ALREADY CORRECT FORMAT: 2024-03-18_B11 2024-03-18 Medisinsk sakkyndig erklæring Dr. Lunde.pdf----
# INFO:data.utils:----ALREADY CORRECT FORMAT: 2022-01-25_B18 Epikriser fra OUS Ullevål.pdf----
# INFO:data.utils:----ALREADY CORRECT FORMAT: 2024-01-22_B20 2024-01-22 Vedtak uføretrygd.pdf----
# WARNING:data.utils:----NO TEXT FOUND: B3 Fotografi av skilt med skivettregler.pdf----
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 2
#       1 for file in Path("./02_org_pdf/Bilag til stevning").glob("*.pdf"):
# ----> 2     rename_pdf_with_date(file, rename=False)
#
# File ~/Documents/Projects/master-thesis/data/src/data/utils.py:154, in rename_pdf_with_date(file, rename, create_date)
#     152 if meta and txt:
#     153     if create_date:
# --> 154         date = parse_pdf_date(meta['/CreationDate'])
#     155     else:
# ...
